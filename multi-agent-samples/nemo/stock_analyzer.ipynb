# %% [markdown]
# Docs to be added

# %%
#install Nemo Agent Toolkit and langchain dependency
# !pip install nvidia-nat
# !pip install "nvidia-nat[langchain]"

# %%
#get the nvidia API key
import getpass
import os

# getpass.getpass() prompts for input without echoing it to the display for security
api_key = getpass.getpass("Enter your NVVIDIA API key: ") 

# You can optionally set it as an environment variable within the session
os.environ["NVIDIA_API_KEY"] = api_key

# Verify the key loaded
print("API key loaded:", "Yes" if os.getenv('NVIDIA_API_KEY') else "No")
